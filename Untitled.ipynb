# %%
# !python3 -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# !python3 -m pip install torchvision tesseract
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-d79yv1i6
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-d79yv1i6
#   Resolved https://github.com/facebookresearch/detectron2.git to commit eddac5d5b4fce9b5eba5518f9ee348fa3a531407
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (9.5.0)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (from detectron2==0.6) (3.5.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: yacs>=0.1.8 in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (4.65.0)
# Requirement already satisfied: tensorboard in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (2.12.3)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: omegaconf>=2.1 in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (1.3.2)
# Requirement already satisfied: black in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (23.3.0)
# Requirement already satisfied: packaging in /home/aarika/.local/lib/python3.10/site-packages (from detectron2==0.6) (23.1)
# Requirement already satisfied: numpy in /home/aarika/.local/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /home/aarika/.local/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (5.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/aarika/.local/lib/python3.10/site-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /home/aarika/.local/lib/python3.10/site-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (2.7.0)
# Requirement already satisfied: click>=8.0.0 in /usr/lib/python3/dist-packages (from black->detectron2==0.6) (8.0.3)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/aarika/.local/lib/python3.10/site-packages (from black->detectron2==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/aarika/.local/lib/python3.10/site-packages (from black->detectron2==0.6) (0.11.1)
# Requirement already satisfied: platformdirs>=2 in /home/aarika/.local/lib/python3.10/site-packages (from black->detectron2==0.6) (3.5.1)
# Requirement already satisfied: tomli>=1.1.0 in /home/aarika/.local/lib/python3.10/site-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: absl-py>=0.4 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.54.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.19.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (4.23.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (67.8.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in /home/aarika/.local/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.40.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/aarika/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/aarika/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/aarika/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/aarika/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (1.12.0)
# Requirement already satisfied: urllib3<2.0 in /home/aarika/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/aarika/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aarika/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/aarika/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aarika/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/aarika/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/aarika/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/aarika/.local/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=5738321 sha256=cbfaa20fd1dc2d4355e4464e1c038af66b9983bb3bfe05e01790d3286d6c392a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cqlt56j4/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
# Successfully built detectron2
# Installing collected packages: detectron2
#   Attempting uninstall: detectron2
#     Found existing installation: detectron2 0.6
#     Uninstalling detectron2-0.6:
#       Successfully uninstalled detectron2-0.6
# Successfully installed detectron2-0.6
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchvision in /home/aarika/.local/lib/python3.10/site-packages (0.15.2)
# Collecting tesseract
#   Using cached tesseract-0.1.3.tar.gz (45.6 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/aarika/.local/lib/python3.10/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /home/aarika/.local/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.0.1 in /home/aarika/.local/lib/python3.10/site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/aarika/.local/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: filelock in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (4.6.2)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch==2.0.1->torchvision) (1.9)
# Requirement already satisfied: networkx in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/aarika/.local/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: setuptools in /home/aarika/.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (67.8.0)
# Requirement already satisfied: wheel in /home/aarika/.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (0.40.0)
# Requirement already satisfied: cmake in /home/aarika/.local/lib/python3.10/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.26.3)
# Requirement already satisfied: lit in /home/aarika/.local/lib/python3.10/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aarika/.local/lib/python3.10/site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/aarika/.local/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aarika/.local/lib/python3.10/site-packages (from requests->torchvision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aarika/.local/lib/python3.10/site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/aarika/.local/lib/python3.10/site-packages (from jinja2->torch==2.0.1->torchvision) (2.1.2)
# Building wheels for collected packages: tesseract
#   Building wheel for tesseract (setup.py) ... done
#   Created wheel for tesseract: filename=tesseract-0.1.3-py3-none-any.whl size=45562552 sha256=3cd149b4424fffb252090ff28092fc841134bd8fdf677c119c1d60bf0b4b196e
#   Stored in directory: /home/aarika/.cache/pip/wheels/71/c9/aa/698c579693e83fdda9ad6d6f0d8f61ed986e27925ef576f109
# Successfully built tesseract
# Installing collected packages: tesseract
# Successfully installed tesseract-0.1.3
